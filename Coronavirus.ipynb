# %% [markdown]
# <a href="https://colab.research.google.com/github/VydEkat/Database/blob/main/Coronavirus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Ссылка на гугл-диск со всеми данными***

# %% [markdown]
# https://drive.google.com/drive/folders/1vMPgOLztvcLhhacNDEBunOn-LUA3qezi?usp=sharing

# %% [markdown]
# # ***Ссылка на csv таблицу только новыми случаями - new_cases***

# %% [markdown]
# https://drive.google.com/file/d/1mJWNn8ZZQfxrrZjI_edtFS-ed1RofVl7/view?usp=sharing

# %% [markdown]
# # ***Ссылка на основную таблицу со всеми данными - owid-covid-data***

# %% [markdown]
# https://drive.google.com/file/d/1aU2NrgFPSxII5bYTvZOS8M8fxgzVK8XU/view?usp=sharing

# %% [markdown]
# # **Импорт данных**

# %%
import pandas as pd
df = pd.read_csv('/content/owid-covid-data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 210208      ZWE    Africa     Zimbabwe  2022-08-16     256561.0       17.0
# 210209      ZWE    Africa     Zimbabwe  2022-08-17     256565.0        4.0
# 210210      ZWE    Africa     Zimbabwe  2022-08-18     256579.0       14.0
# 210211      ZWE    Africa     Zimbabwe  2022-08-19     256596.0       17.0
# 210212      ZWE    Africa     Zimbabwe  2022-08-20     256616.0       20.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 210208              10.143        5588.0         0.0                0.286
# 210209              10.429        5588.0         0.0                0.143
# 210210               9.429        5589.0         1.0                0.286
# 210211              10.571        5589.0         0.0                0.286
# 210212              13.429        5592.0         3.0                0.714
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 210208  ...             1.6          30.7                  36.791
# 210209  ...             1.6          30.7                  36.791
# 210210  ...             1.6          30.7                  36.791
# 210211  ...             1.6          30.7                  36.791
# 210212  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 210208                         1.7            61.49                    0.571
# 210209                         1.7            61.49                    0.571
# 210210                         1.7            61.49                    0.571
# 210211                         1.7            61.49                    0.571
# 210212                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 210208                                   NaN                          NaN
# 210209                                   NaN                          NaN
# 210210                                   NaN                          NaN
# 210211                                   NaN                          NaN
# 210212                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 210208               NaN                                      NaN
# 210209               NaN                                      NaN
# 210210               NaN                                      NaN
# 210211               NaN                                      NaN
# 210212               NaN                                      NaN
#
# [210213 rows x 67 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %% [markdown]
# # **Немного исследуем данные**

# %%
df[df['location'].isin(['Russia', 'United States', 'China', 'United Kingdom', 'India', 'Spain', 'Germany','Chile', 'Algeria', 'Australia', 'Vietnam', 'Canada'])]
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 2737        DZA    Africa  Algeria  2020-02-25          1.0        1.0
# 2738        DZA    Africa  Algeria  2020-02-26          1.0        0.0
# 2739        DZA    Africa  Algeria  2020-02-27          1.0        0.0
# 2740        DZA    Africa  Algeria  2020-02-28          1.0        0.0
# 2741        DZA    Africa  Algeria  2020-02-29          1.0        0.0
# ...         ...       ...      ...         ...          ...        ...
# 205961      VNM      Asia  Vietnam  2022-08-16   11370462.0     2983.0
# 205962      VNM      Asia  Vietnam  2022-08-17   11373276.0     2814.0
# 205963      VNM      Asia  Vietnam  2022-08-18   11376571.0     3295.0
# 205964      VNM      Asia  Vietnam  2022-08-19   11379554.0     2983.0
# 205965      VNM      Asia  Vietnam  2022-08-20   11382258.0     2704.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 2737                   NaN           NaN         NaN                  NaN
# 2738                   NaN           NaN         NaN                  NaN
# 2739                   NaN           NaN         NaN                  NaN
# 2740                   NaN           NaN         NaN                  NaN
# 2741                   NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 205961            2699.857       43100.0         2.0                0.857
# 205962            2814.714       43103.0         3.0                1.143
# 205963            2317.571       43103.0         0.0                1.143
# 205964            2430.571       43103.0         0.0                1.000
# 205965            2557.571       43104.0         1.0                1.000
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 2737    ...             0.7          30.4                  83.741
# 2738    ...             0.7          30.4                  83.741
# 2739    ...             0.7          30.4                  83.741
# 2740    ...             0.7          30.4                  83.741
# 2741    ...             0.7          30.4                  83.741
# ...     ...             ...           ...                     ...
# 205961  ...             1.0          45.9                  85.847
# 205962  ...             1.0          45.9                  85.847
# 205963  ...             1.0          45.9                  85.847
# 205964  ...             1.0          45.9                  85.847
# 205965  ...             1.0          45.9                  85.847
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 2737                           1.9            76.88                    0.748
# 2738                           1.9            76.88                    0.748
# 2739                           1.9            76.88                    0.748
# 2740                           1.9            76.88                    0.748
# 2741                           1.9            76.88                    0.748
# ...                            ...              ...                      ...
# 205961                         2.6            75.40                    0.704
# 205962                         2.6            75.40                    0.704
# 205963                         2.6            75.40                    0.704
# 205964                         2.6            75.40                    0.704
# 205965                         2.6            75.40                    0.704
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 2737                                     NaN                          NaN
# 2738                                     NaN                          NaN
# 2739                                     NaN                          NaN
# 2740                                     NaN                          NaN
# 2741                                  -536.3                         -1.6
# ...                                      ...                          ...
# 205961                                   NaN                          NaN
# 205962                                   NaN                          NaN
# 205963                                   NaN                          NaN
# 205964                                   NaN                          NaN
# 205965                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 2737                 NaN                                      NaN
# 2738                 NaN                                      NaN
# 2739                 NaN                                      NaN
# 2740                 NaN                                      NaN
# 2741               -0.61                               -12.139535
# ...                  ...                                      ...
# 205961               NaN                                      NaN
# 205962               NaN                                      NaN
# 205963               NaN                                      NaN
# 205964               NaN                                      NaN
# 205965               NaN                                      NaN
#
# [11191 rows x 67 columns]

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana',
#        'Haiti', 'High income', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'International', 'Iran', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low income',
#        'Lower middle income', 'Luxembourg', 'Macao', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico',
#        'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar',
#        'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia',
#        'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#        'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Mariana Islands', 'Norway', 'Oceania',
#        'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania', 'Russia',
#        'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df.isna().mean()
# Out:
# iso_code                                   0.000000
# continent                                  0.057751
# location                                   0.000000
# date                                       0.000000
# total_cases                                0.040606
#                                              ...
# human_development_index                    0.199174
# excess_mortality_cumulative_absolute       0.966068
# excess_mortality_cumulative                0.966068
# excess_mortality                           0.965973
# excess_mortality_cumulative_per_million    0.966068
# Length: 67, dtype: float64

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# weekly_icu_admissions_per_million          0.967219
# weekly_icu_admissions                      0.967219
# excess_mortality_cumulative_per_million    0.966068
# excess_mortality_cumulative                0.966068
# excess_mortality_cumulative_absolute       0.966068
#                                              ...
# total_cases                                0.040606
# population                                 0.005913
# date                                       0.000000
# location                                   0.000000
# iso_code                                   0.000000
# Length: 67, dtype: float64

# %%
cols_to_delete = df.columns[df.isna().mean() > 0.8]

# %%
cols_to_delete
# Out:
# Index(['icu_patients', 'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_boosters',
#        'total_boosters_per_hundred', 'excess_mortality_cumulative_absolute',
#        'excess_mortality_cumulative', 'excess_mortality',
#        'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
cols_to_delete = df.columns[df.isna().mean() > 0.8]
df = df.drop(cols_to_delete, axis = 1) #убрали столбцы с большим количеством NaN

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 210208      ZWE    Africa     Zimbabwe  2022-08-16     256561.0       17.0
# 210209      ZWE    Africa     Zimbabwe  2022-08-17     256565.0        4.0
# 210210      ZWE    Africa     Zimbabwe  2022-08-18     256579.0       14.0
# 210211      ZWE    Africa     Zimbabwe  2022-08-19     256596.0       17.0
# 210212      ZWE    Africa     Zimbabwe  2022-08-20     256616.0       20.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 210208              10.143        5588.0         0.0                0.286
# 210209              10.429        5588.0         0.0                0.143
# 210210               9.429        5589.0         1.0                0.286
# 210211              10.571        5589.0         0.0                0.286
# 210212              13.429        5592.0         3.0                0.714
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       ...        1803.987              NaN                597.029
# 1       ...        1803.987              NaN                597.029
# 2       ...        1803.987              NaN                597.029
# 3       ...        1803.987              NaN                597.029
# 4       ...        1803.987              NaN                597.029
# ...     ...             ...              ...                    ...
# 210208  ...        1899.775             21.4                307.846
# 210209  ...        1899.775             21.4                307.846
# 210210  ...        1899.775             21.4                307.846
# 210211  ...        1899.775             21.4                307.846
# 210212  ...        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 0                      9.59             NaN           NaN
# 1                      9.59             NaN           NaN
# 2                      9.59             NaN           NaN
# 3                      9.59             NaN           NaN
# 4                      9.59             NaN           NaN
# ...                     ...             ...           ...
# 210208                 1.82             1.6          30.7
# 210209                 1.82             1.6          30.7
# 210210                 1.82             1.6          30.7
# 210211                 1.82             1.6          30.7
# 210212                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       37.746                         0.5            64.83
# 1                       37.746                         0.5            64.83
# 2                       37.746                         0.5            64.83
# 3                       37.746                         0.5            64.83
# 4                       37.746                         0.5            64.83
# ...                        ...                         ...              ...
# 210208                  36.791                         1.7            61.49
# 210209                  36.791                         1.7            61.49
# 210210                  36.791                         1.7            61.49
# 210211                  36.791                         1.7            61.49
# 210212                  36.791                         1.7            61.49
#
#         human_development_index
# 0                         0.511
# 1                         0.511
# 2                         0.511
# 3                         0.511
# 4                         0.511
# ...                         ...
# 210208                    0.571
# 210209                    0.571
# 210210                    0.571
# 210211                    0.571
# 210212                    0.571
#
# [210213 rows x 53 columns]

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
df['continent'].hist()

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.016770e+05  2.013780e+05        2.002010e+05  1.828590e+05
# mean   3.932490e+06  1.262194e+04        1.263733e+04  6.991495e+04
# std    2.467174e+07  8.722419e+04        8.520482e+04  3.618313e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    3.593000e+03  0.000000e+00        6.714000e+00  1.050000e+02
# 50%    4.289800e+04  6.400000e+01        1.004290e+02  1.061000e+03
# 75%    4.626050e+05  1.010000e+03        1.157714e+03  9.201000e+03
# max    5.956908e+08  4.079205e+06        3.436703e+06  6.452877e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  182816.000000        181644.000000            200751.000000
# mean      146.464363           147.169270             51896.974889
# std       755.372885           738.910114             94310.065563
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.143000               931.889000
# 50%         1.000000             1.714000              8515.720000
# 75%        15.000000            17.000000             63091.242000
# max     18191.000000         14817.143000            655309.333000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          200452.000000                   199280.000000
# mean              189.851431                      189.675620
# std               935.442532                      610.332991
# min                 0.000000                        0.000000
# 25%                 0.000000                        1.479000
# 50%                 9.007000                       20.126000
# 75%               102.462000                      137.176250
# max            195005.313000                    35258.843000
#
#        total_deaths_per_million  ...  gdp_per_capita  extreme_poverty  \
# count             181946.000000  ...   172378.000000    112463.000000
# mean                 647.524065  ...    19586.847732        13.622943
# std                  935.192794  ...    20559.649061        20.029750
# min                    0.000000  ...      661.240000         0.100000
# 25%                   27.003000  ...     4449.898000         0.600000
# 50%                  188.774500  ...    12951.839000         2.200000
# 75%                  956.573000  ...    27936.896000        21.200000
# max                 6386.296000  ...   116935.600000        77.600000
#
#        cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# count          172794.000000        181481.000000   130728.000000
# mean              261.006296             8.375898       10.658286
# std               119.934659             4.713929       10.602668
# min                79.370000             0.990000        0.100000
# 25%               170.050000             5.310000        1.900000
# 50%               243.964000             7.200000        6.300000
# 75%               329.942000            10.590000       19.300000
# max               724.417000            30.530000       44.000000
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# count  128937.000000            84887.000000               153565.000000
# mean       32.802058               50.866857                    3.084569
# std        13.534061               31.845325                    2.550856
# min         7.700000                1.188000                    0.100000
# 25%        21.600000               20.859000                    1.300000
# 50%        31.400000               49.839000                    2.500000
# 75%        41.300000               82.502000                    4.000000
# max        78.100000              100.000000                   13.800000
#
#        life_expectancy  human_development_index
# count    196669.000000            168344.000000
# mean         73.640281                 0.724963
# std           7.447933                 0.149703
# min          53.280000                 0.394000
# 25%          69.500000                 0.602000
# 50%          75.050000                 0.743000
# 75%          79.070000                 0.845000
# max          86.750000                 0.957000
#
# [8 rows x 48 columns]

# %% [markdown]
# **Корреляция по всем значениям**

# %%
import numpy as np
import matplotlib.pylab as plt
import statsmodels.api as sm
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = [15, 15]
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf8c3c3850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e5d1a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e4c7350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e48be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e44b390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e3fd890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e42ee10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e3ee290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e3ee2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e3a38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf8de34e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf8034ed10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf80181950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf80cd9e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7ffd60d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e275990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e224f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e1e45d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e19bbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e15f210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e116810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e0cde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e091450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e046a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7e075b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dfc2690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dff8c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7df3c2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7df758d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7df2ced0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7deef510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dea6b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7de69190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7de20790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7ddd7d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dd9c3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dd53990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dcfeb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dccd610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dc83c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dc3dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dc032d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dc387d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dbefcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dbb3210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7db6a710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7db1fc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7dae3150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fdf7da9b650>]],
#       dtype=object)

# %%
df[df['location'] == 'Russia']
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 155988      RUS    Europe   Russia  2020-01-31          2.0        2.0
# 155989      RUS    Europe   Russia  2020-02-01          2.0        0.0
# 155990      RUS    Europe   Russia  2020-02-02          2.0        0.0
# 155991      RUS    Europe   Russia  2020-02-03          2.0        0.0
# 155992      RUS    Europe   Russia  2020-02-04          2.0        0.0
# ...         ...       ...      ...         ...          ...        ...
# 156916      RUS    Europe   Russia  2022-08-16   18655654.0    23489.0
# 156917      RUS    Europe   Russia  2022-08-17   18688416.0    32762.0
# 156918      RUS    Europe   Russia  2022-08-18   18723731.0    35315.0
# 156919      RUS    Europe   Russia  2022-08-19   18760762.0    37031.0
# 156920      RUS    Europe   Russia  2022-08-20   18800180.0    39418.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 155988                 NaN           NaN         NaN                  NaN
# 155989                 NaN           NaN         NaN                  NaN
# 155990                 NaN           NaN         NaN                  NaN
# 155991                 NaN           NaN         NaN                  NaN
# 155992                 NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 156916           25959.143      375470.0        57.0               55.000
# 156917           27275.286      375532.0        62.0               56.000
# 156918           28671.857      375594.0        62.0               57.429
# 156919           30034.286      375658.0        64.0               58.571
# 156920           31635.571      375725.0        67.0               59.857
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 155988  ...       24765.954              0.1                431.297
# 155989  ...       24765.954              0.1                431.297
# 155990  ...       24765.954              0.1                431.297
# 155991  ...       24765.954              0.1                431.297
# 155992  ...       24765.954              0.1                431.297
# ...     ...             ...              ...                    ...
# 156916  ...       24765.954              0.1                431.297
# 156917  ...       24765.954              0.1                431.297
# 156918  ...       24765.954              0.1                431.297
# 156919  ...       24765.954              0.1                431.297
# 156920  ...       24765.954              0.1                431.297
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 155988                 6.18            23.4          58.3
# 155989                 6.18            23.4          58.3
# 155990                 6.18            23.4          58.3
# 155991                 6.18            23.4          58.3
# 155992                 6.18            23.4          58.3
# ...                     ...             ...           ...
# 156916                 6.18            23.4          58.3
# 156917                 6.18            23.4          58.3
# 156918                 6.18            23.4          58.3
# 156919                 6.18            23.4          58.3
# 156920                 6.18            23.4          58.3
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 155988                     NaN                        8.05            72.58
# 155989                     NaN                        8.05            72.58
# 155990                     NaN                        8.05            72.58
# 155991                     NaN                        8.05            72.58
# 155992                     NaN                        8.05            72.58
# ...                        ...                         ...              ...
# 156916                     NaN                        8.05            72.58
# 156917                     NaN                        8.05            72.58
# 156918                     NaN                        8.05            72.58
# 156919                     NaN                        8.05            72.58
# 156920                     NaN                        8.05            72.58
#
#         human_development_index
# 155988                    0.824
# 155989                    0.824
# 155990                    0.824
# 155991                    0.824
# 155992                    0.824
# ...                         ...
# 156916                    0.824
# 156917                    0.824
# 156918                    0.824
# 156919                    0.824
# 156920                    0.824
#
# [933 rows x 53 columns]

# %%
df[df['date'] > '2021-01-01']
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 313         AFG      Asia  Afghanistan  2021-01-02      52586.0       73.0
# 314         AFG      Asia  Afghanistan  2021-01-03      52709.0      123.0
# 315         AFG      Asia  Afghanistan  2021-01-04      52909.0      200.0
# 316         AFG      Asia  Afghanistan  2021-01-05      53011.0      102.0
# 317         AFG      Asia  Afghanistan  2021-01-06      53105.0       94.0
# ...         ...       ...          ...         ...          ...        ...
# 210208      ZWE    Africa     Zimbabwe  2022-08-16     256561.0       17.0
# 210209      ZWE    Africa     Zimbabwe  2022-08-17     256565.0        4.0
# 210210      ZWE    Africa     Zimbabwe  2022-08-18     256579.0       14.0
# 210211      ZWE    Africa     Zimbabwe  2022-08-19     256596.0       17.0
# 210212      ZWE    Africa     Zimbabwe  2022-08-20     256616.0       20.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 313                117.429        2211.0        10.0                9.000
# 314                123.000        2221.0        10.0                9.000
# 315                128.857        2230.0         9.0                8.571
# 316                123.429        2237.0         7.0                7.857
# 317                110.714        2244.0         7.0                7.857
# ...                    ...           ...         ...                  ...
# 210208              10.143        5588.0         0.0                0.286
# 210209              10.429        5588.0         0.0                0.143
# 210210               9.429        5589.0         1.0                0.286
# 210211              10.571        5589.0         0.0                0.286
# 210212              13.429        5592.0         3.0                0.714
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 313     ...        1803.987              NaN                597.029
# 314     ...        1803.987              NaN                597.029
# 315     ...        1803.987              NaN                597.029
# 316     ...        1803.987              NaN                597.029
# 317     ...        1803.987              NaN                597.029
# ...     ...             ...              ...                    ...
# 210208  ...        1899.775             21.4                307.846
# 210209  ...        1899.775             21.4                307.846
# 210210  ...        1899.775             21.4                307.846
# 210211  ...        1899.775             21.4                307.846
# 210212  ...        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 313                    9.59             NaN           NaN
# 314                    9.59             NaN           NaN
# 315                    9.59             NaN           NaN
# 316                    9.59             NaN           NaN
# 317                    9.59             NaN           NaN
# ...                     ...             ...           ...
# 210208                 1.82             1.6          30.7
# 210209                 1.82             1.6          30.7
# 210210                 1.82             1.6          30.7
# 210211                 1.82             1.6          30.7
# 210212                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 313                     37.746                         0.5            64.83
# 314                     37.746                         0.5            64.83
# 315                     37.746                         0.5            64.83
# 316                     37.746                         0.5            64.83
# 317                     37.746                         0.5            64.83
# ...                        ...                         ...              ...
# 210208                  36.791                         1.7            61.49
# 210209                  36.791                         1.7            61.49
# 210210                  36.791                         1.7            61.49
# 210211                  36.791                         1.7            61.49
# 210212                  36.791                         1.7            61.49
#
#         human_development_index
# 313                       0.511
# 314                       0.511
# 315                       0.511
# 316                       0.511
# 317                       0.511
# ...                         ...
# 210208                    0.571
# 210209                    0.571
# 210210                    0.571
# 210211                    0.571
# 210212                    0.571
#
# [141620 rows x 53 columns]

# %% [markdown]
# # **Отбор 2020-2022 по России**

# %%
df_Russia2020 = df.loc[(df['location'] == 'Russia') & (df['date'] >= '2020-01-01') & (df['date'] < '2021-01-01')] #Данные о России за 2020 год

# %%
df_Russia2020
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 155988      RUS    Europe   Russia  2020-01-31          2.0        2.0
# 155989      RUS    Europe   Russia  2020-02-01          2.0        0.0
# 155990      RUS    Europe   Russia  2020-02-02          2.0        0.0
# 155991      RUS    Europe   Russia  2020-02-03          2.0        0.0
# 155992      RUS    Europe   Russia  2020-02-04          2.0        0.0
# ...         ...       ...      ...         ...          ...        ...
# 156319      RUS    Europe   Russia  2020-12-27    3019972.0    27849.0
# 156320      RUS    Europe   Russia  2020-12-28    3047335.0    27363.0
# 156321      RUS    Europe   Russia  2020-12-29    3073923.0    26588.0
# 156322      RUS    Europe   Russia  2020-12-30    3100018.0    26095.0
# 156323      RUS    Europe   Russia  2020-12-31    3127347.0    27329.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 155988                 NaN           NaN         NaN                  NaN
# 155989                 NaN           NaN         NaN                  NaN
# 155990                 NaN           NaN         NaN                  NaN
# 155991                 NaN           NaN         NaN                  NaN
# 155992                 NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 156319           28406.714       54080.0       541.0              548.286
# 156320           28184.714       54559.0       479.0              548.000
# 156321           27934.429       55107.0       548.0              547.571
# 156322           27831.714       55692.0       585.0              554.571
# 156323           27521.714       56271.0       579.0              548.143
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 155988  ...       24765.954              0.1                431.297
# 155989  ...       24765.954              0.1                431.297
# 155990  ...       24765.954              0.1                431.297
# 155991  ...       24765.954              0.1                431.297
# 155992  ...       24765.954              0.1                431.297
# ...     ...             ...              ...                    ...
# 156319  ...       24765.954              0.1                431.297
# 156320  ...       24765.954              0.1                431.297
# 156321  ...       24765.954              0.1                431.297
# 156322  ...       24765.954              0.1                431.297
# 156323  ...       24765.954              0.1                431.297
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 155988                 6.18            23.4          58.3
# 155989                 6.18            23.4          58.3
# 155990                 6.18            23.4          58.3
# 155991                 6.18            23.4          58.3
# 155992                 6.18            23.4          58.3
# ...                     ...             ...           ...
# 156319                 6.18            23.4          58.3
# 156320                 6.18            23.4          58.3
# 156321                 6.18            23.4          58.3
# 156322                 6.18            23.4          58.3
# 156323                 6.18            23.4          58.3
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 155988                     NaN                        8.05            72.58
# 155989                     NaN                        8.05            72.58
# 155990                     NaN                        8.05            72.58
# 155991                     NaN                        8.05            72.58
# 155992                     NaN                        8.05            72.58
# ...                        ...                         ...              ...
# 156319                     NaN                        8.05            72.58
# 156320                     NaN                        8.05            72.58
# 156321                     NaN                        8.05            72.58
# 156322                     NaN                        8.05            72.58
# 156323                     NaN                        8.05            72.58
#
#         human_development_index
# 155988                    0.824
# 155989                    0.824
# 155990                    0.824
# 155991                    0.824
# 155992                    0.824
# ...                         ...
# 156319                    0.824
# 156320                    0.824
# 156321                    0.824
# 156322                    0.824
# 156323                    0.824
#
# [336 rows x 53 columns]

# %%
df_Russia2020[['new_cases', 'stringency_index']].corr()
# Out:
#                   new_cases  stringency_index
# new_cases          1.000000          0.039512
# stringency_index   0.039512          1.000000

# %%
df_Russia2021 = df.loc[(df['location'] == 'Russia') & (df['date'] >= '2021-01-01') & (df['date'] < '2022-01-01')] #Данные о России за 2021 год

# %%
df_Russia2022 = df.loc[(df['location'] == 'Russia') & (df['date'] >= '2022-01-01') & (df['date'] < '2023-01-01')] #Данные о России за 2022 год

# %%
df_Russia2021[['new_cases', 'stringency_index']].corr()
# Out:
#                   new_cases  stringency_index
# new_cases          1.000000          0.529877
# stringency_index   0.529877          1.000000

# %%
df_Russia2022[['new_cases', 'stringency_index']].corr()
# Out:
#                   new_cases  stringency_index
# new_cases          1.000000          0.440516
# stringency_index   0.440516          1.000000

# %%
df_Russia2020[['new_deaths', 'stringency_index']].corr()
# Out:
#                   new_deaths  stringency_index
# new_deaths           1.00000          -0.53252
# stringency_index    -0.53252           1.00000

# %%
df_Russia2021[['new_deaths', 'stringency_index']].corr()
# Out:
#                   new_deaths  stringency_index
# new_deaths          1.000000          0.555607
# stringency_index    0.555607          1.000000

# %%
df_Russia2022[['new_deaths', 'stringency_index']].corr()
# Out:
#                   new_deaths  stringency_index
# new_deaths          1.000000          0.835728
# stringency_index    0.835728          1.000000

# %%
df_Russia2020[['new_tests', 'stringency_index', 'date']]
# Out:
#         new_tests  stringency_index        date
# 155988        NaN              8.33  2020-01-31
# 155989        NaN              8.33  2020-02-01
# 155990        NaN              8.33  2020-02-02
# 155991        NaN              8.33  2020-02-03
# 155992        NaN              8.33  2020-02-04
# ...           ...               ...         ...
# 156319   416572.0             47.69  2020-12-27
# 156320   292690.0             47.69  2020-12-28
# 156321   395008.0             47.69  2020-12-29
# 156322   445015.0             47.69  2020-12-30
# 156323   474243.0             47.69  2020-12-31
#
# [336 rows x 3 columns]

# %%
df_Russia2020[['new_deaths', 'new_tests']].corr()
# Out:
#             new_deaths  new_tests
# new_deaths    1.000000   0.810188
# new_tests     0.810188   1.000000

# %%
df_Russia2021[['new_deaths', 'new_tests']].corr()
# Out:
#             new_deaths  new_tests
# new_deaths    1.000000   0.721956
# new_tests     0.721956   1.000000

# %%
df_Russia2022[['new_deaths', 'new_tests']].corr()
# Out:
#             new_deaths  new_tests
# new_deaths    1.000000  -0.780845
# new_tests    -0.780845   1.000000

# %%
df_Russia2022[['new_deaths', 'new_tests', 'date']]
# Out:
#         new_deaths  new_tests        date
# 156689       825.0        NaN  2022-01-01
# 156690       788.0        NaN  2022-01-02
# 156691       812.0        NaN  2022-01-03
# 156692       810.0        NaN  2022-01-04
# 156693       804.0        NaN  2022-01-05
# ...            ...        ...         ...
# 156916        57.0        NaN  2022-08-16
# 156917        62.0        NaN  2022-08-17
# 156918        62.0        NaN  2022-08-18
# 156919        64.0        NaN  2022-08-19
# 156920        67.0        NaN  2022-08-20
#
# [232 rows x 3 columns]

# %%
df_Russia2021[['new_deaths', 'new_tests']].corr()
# Out:
#             new_deaths  new_tests
# new_deaths    1.000000   0.721956
# new_tests     0.721956   1.000000

# %% [markdown]
# # **Тепловая карта**

# %%
df.corr()
# Out:
#                                             total_cases  new_cases  \
# total_cases                                    1.000000   0.731061
# new_cases                                      0.731061   1.000000
# new_cases_smoothed                             0.754282   0.973794
# total_deaths                                   0.939475   0.730854
# new_deaths                                     0.505052   0.646462
# new_deaths_smoothed                            0.522235   0.633998
# total_cases_per_million                        0.098195   0.064447
# new_cases_per_million                          0.018839   0.071275
# new_cases_smoothed_per_million                 0.029708   0.091018
# total_deaths_per_million                       0.118575   0.078915
# new_deaths_per_million                         0.001896   0.029699
# new_deaths_smoothed_per_million                0.003567   0.036291
# reproduction_rate                              0.009324   0.028462
# total_tests                                    0.858065   0.446180
# new_tests                                      0.577082   0.546702
# total_tests_per_thousand                       0.095789   0.071034
# new_tests_per_thousand                         0.011832   0.069481
# new_tests_smoothed                             0.088555   0.082946
# new_tests_smoothed_per_thousand                0.017726   0.075669
# positive_rate                                  0.044091   0.177211
# tests_per_case                                -0.017767  -0.015175
# total_vaccinations                             0.830995   0.588267
# people_vaccinated                              0.833328   0.597250
# people_fully_vaccinated                        0.833250   0.592041
# new_vaccinations                               0.522059   0.489318
# new_vaccinations_smoothed                      0.554107   0.509306
# total_vaccinations_per_hundred                 0.138448   0.088542
# people_vaccinated_per_hundred                  0.132980   0.077173
# people_fully_vaccinated_per_hundred            0.119825   0.074163
# new_vaccinations_smoothed_per_million         -0.006092   0.015813
# new_people_vaccinated_smoothed                 0.445571   0.388914
# new_people_vaccinated_smoothed_per_hundred    -0.029480  -0.021824
# stringency_index                              -0.070479   0.012371
# population                                     0.611801   0.541481
# population_density                            -0.016377  -0.014901
# median_age                                     0.037075   0.043232
# aged_65_older                                  0.036341   0.044132
# aged_70_older                                  0.034495   0.043439
# gdp_per_capita                                 0.015033   0.019298
# extreme_poverty                               -0.036235  -0.035504
# cardiovasc_death_rate                         -0.039849  -0.044222
# diabetes_prevalence                            0.005008   0.001034
# female_smokers                                 0.001640   0.006417
# male_smokers                                  -0.003540   0.000662
# handwashing_facilities                         0.032427   0.030710
# hospital_beds_per_thousand                     0.003269   0.016842
# life_expectancy                                0.017817   0.023590
# human_development_index                        0.041663   0.045534
#
#                                             new_cases_smoothed  total_deaths  \
# total_cases                                           0.754282      0.939475
# new_cases                                             0.973794      0.730854
# new_cases_smoothed                                    1.000000      0.749990
# total_deaths                                          0.749990      1.000000
# new_deaths                                            0.640522      0.656501
# new_deaths_smoothed                                   0.653617      0.677635
# total_cases_per_million                               0.067448      0.048891
# new_cases_per_million                                 0.060738      0.005551
# new_cases_smoothed_per_million                        0.093602      0.007913
# total_deaths_per_million                              0.081610      0.130662
# new_deaths_per_million                                0.026159      0.009731
# new_deaths_smoothed_per_million                       0.038726      0.015731
# reproduction_rate                                     0.022756      0.013695
# total_tests                                           0.474076      0.770267
# new_tests                                             0.555584      0.577643
# total_tests_per_thousand                              0.075808      0.028133
# new_tests_per_thousand                                0.065715     -0.011294
# new_tests_smoothed                                    0.087348      0.081698
# new_tests_smoothed_per_thousand                       0.078004     -0.011456
# positive_rate                                         0.191057      0.031187
# tests_per_case                                       -0.016011     -0.018504
# total_vaccinations                                    0.604175      0.826699
# people_vaccinated                                     0.612658      0.849544
# people_fully_vaccinated                               0.607664      0.828479
# new_vaccinations                                      0.485538      0.666986
# new_vaccinations_smoothed                             0.517216      0.693774
# total_vaccinations_per_hundred                        0.091022      0.084556
# people_vaccinated_per_hundred                         0.078856      0.092596
# people_fully_vaccinated_per_hundred                   0.075644      0.067215
# new_vaccinations_smoothed_per_million                 0.014697      0.025496
# new_people_vaccinated_smoothed                        0.394948      0.595060
# new_people_vaccinated_smoothed_per_hundred           -0.022617     -0.003849
# stringency_index                                      0.011703     -0.017010
# population                                            0.554938      0.701596
# population_density                                   -0.015229     -0.020136
# median_age                                            0.043976      0.032688
# aged_65_older                                         0.044845      0.028114
# aged_70_older                                         0.044118      0.025510
# gdp_per_capita                                        0.019586      0.005910
# extreme_poverty                                      -0.036207     -0.043564
# cardiovasc_death_rate                                -0.045027     -0.038108
# diabetes_prevalence                                   0.001110      0.014258
# female_smokers                                        0.006482     -0.007014
# male_smokers                                          0.000628     -0.002238
# handwashing_facilities                                0.031274      0.042517
# hospital_beds_per_thousand                            0.016802     -0.006930
# life_expectancy                                       0.023949      0.015896
# human_development_index                               0.046370      0.038723
#
#                                             new_deaths  new_deaths_smoothed  \
# total_cases                                   0.505052             0.522235
# new_cases                                     0.646462             0.633998
# new_cases_smoothed                            0.640522             0.653617
# total_deaths                                  0.656501             0.677635
# new_deaths                                    1.000000             0.974683
# new_deaths_smoothed                           0.974683             1.000000
# total_cases_per_million                      -0.021568            -0.021851
# new_cases_per_million                         0.008810             0.004125
# new_cases_smoothed_per_million                0.007527             0.006760
# total_deaths_per_million                      0.039061             0.040897
# new_deaths_per_million                        0.070461             0.060202
# new_deaths_smoothed_per_million               0.088390             0.090829
# reproduction_rate                             0.017562             0.015647
# total_tests                                   0.365045             0.393297
# new_tests                                     0.509029             0.511101
# total_tests_per_thousand                     -0.032843            -0.034437
# new_tests_per_thousand                       -0.014721            -0.020330
# new_tests_smoothed                            0.068496             0.072507
# new_tests_smoothed_per_thousand              -0.012771            -0.014315
# positive_rate                                 0.123734             0.125274
# tests_per_case                               -0.019642            -0.021011
# total_vaccinations                            0.385585             0.399296
# people_vaccinated                             0.423179             0.438110
# people_fully_vaccinated                       0.373110             0.386325
# new_vaccinations                              0.641626             0.646898
# new_vaccinations_smoothed                     0.645874             0.666160
# total_vaccinations_per_hundred               -0.099752            -0.101792
# people_vaccinated_per_hundred                -0.111863            -0.113961
# people_fully_vaccinated_per_hundred          -0.128042            -0.131225
# new_vaccinations_smoothed_per_million         0.029961             0.031743
# new_people_vaccinated_smoothed                0.630035             0.648795
# new_people_vaccinated_smoothed_per_hundred    0.022607             0.024162
# stringency_index                              0.134048             0.142847
# population                                    0.706957             0.726043
# population_density                           -0.020600            -0.021099
# median_age                                    0.035742             0.036548
# aged_65_older                                 0.030889             0.031562
# aged_70_older                                 0.028181             0.028781
# gdp_per_capita                                0.006708             0.006821
# extreme_poverty                              -0.045517            -0.046576
# cardiovasc_death_rate                        -0.035999            -0.036761
# diabetes_prevalence                           0.014447             0.014868
# female_smokers                               -0.005814            -0.005954
# male_smokers                                  0.002964             0.003111
# handwashing_facilities                        0.044504             0.045438
# hospital_beds_per_thousand                   -0.002407            -0.002455
# life_expectancy                               0.016258             0.016606
# human_development_index                       0.040794             0.041722
#
#                                             total_cases_per_million  \
# total_cases                                                0.098195
# new_cases                                                  0.064447
# new_cases_smoothed                                         0.067448
# total_deaths                                               0.048891
# new_deaths                                                -0.021568
# new_deaths_smoothed                                       -0.021851
# total_cases_per_million                                    1.000000
# new_cases_per_million                                      0.265870
# new_cases_smoothed_per_million                             0.420705
# total_deaths_per_million                                   0.616895
# new_deaths_per_million                                     0.084442
# new_deaths_smoothed_per_million                            0.132707
# reproduction_rate                                         -0.020014
# total_tests                                                0.203017
# new_tests                                                  0.092837
# total_tests_per_thousand                                   0.588508
# new_tests_per_thousand                                     0.258806
# new_tests_smoothed                                        -0.032098
# new_tests_smoothed_per_thousand                            0.291911
# positive_rate                                              0.287640
# tests_per_case                                            -0.046190
# total_vaccinations                                        -0.065043
# people_vaccinated                                         -0.068844
# people_fully_vaccinated                                   -0.062650
# new_vaccinations                                          -0.145486
# new_vaccinations_smoothed                                 -0.068530
# total_vaccinations_per_hundred                             0.588856
# people_vaccinated_per_hundred                              0.518761
# people_fully_vaccinated_per_hundred                        0.545413
# new_vaccinations_smoothed_per_million                     -0.082695
# new_people_vaccinated_smoothed                            -0.072603
# new_people_vaccinated_smoothed_per_hundred                -0.153631
# stringency_index                                          -0.344666
# population                                                -0.056299
# population_density                                         0.021430
# median_age                                                 0.393930
# aged_65_older                                              0.376345
# aged_70_older                                              0.375582
# gdp_per_capita                                             0.296431
# extreme_poverty                                           -0.304806
# cardiovasc_death_rate                                     -0.200398
# diabetes_prevalence                                        0.037534
# female_smokers                                             0.351466
# male_smokers                                               0.060653
# handwashing_facilities                                     0.392375
# hospital_beds_per_thousand                                 0.226266
# life_expectancy                                            0.350034
# human_development_index                                    0.412741
#
#                                             new_cases_per_million  \
# total_cases                                              0.018839
# new_cases                                                0.071275
# new_cases_smoothed                                       0.060738
# total_deaths                                             0.005551
# new_deaths                                               0.008810
# new_deaths_smoothed                                      0.004125
# total_cases_per_million                                  0.265870
# new_cases_per_million                                    1.000000
# new_cases_smoothed_per_million                           0.674096
# total_deaths_per_million                                 0.163937
# new_deaths_per_million                                   0.241858
# new_deaths_smoothed_per_million                          0.201250
# reproduction_rate                                        0.105524
# total_tests                                              0.072456
# new_tests                                                0.114720
# total_tests_per_thousand                                 0.345400
# new_tests_per_thousand                                   0.338580
# new_tests_smoothed                                      -0.005212
# new_tests_smoothed_per_thousand                          0.351373
# positive_rate                                            0.353553
# tests_per_case                                          -0.023361
# total_vaccinations                                      -0.047196
# people_vaccinated                                       -0.049110
# people_fully_vaccinated                                 -0.044746
# new_vaccinations                                        -0.072067
# new_vaccinations_smoothed                               -0.027794
# total_vaccinations_per_hundred                           0.279012
# people_vaccinated_per_hundred                            0.244578
# people_fully_vaccinated_per_hundred                      0.257616
# new_vaccinations_smoothed_per_million                    0.056077
# new_people_vaccinated_smoothed                          -0.031483
# new_people_vaccinated_smoothed_per_hundred              -0.037423
# stringency_index                                        -0.056613
# population                                              -0.023474
# population_density                                       0.018190
# median_age                                               0.223466
# aged_65_older                                            0.220115
# aged_70_older                                            0.220507
# gdp_per_capita                                           0.161016
# extreme_poverty                                         -0.162969
# cardiovasc_death_rate                                   -0.116375
# diabetes_prevalence                                      0.028528
# female_smokers                                           0.186389
# male_smokers                                             0.021394
# handwashing_facilities                                   0.136974
# hospital_beds_per_thousand                               0.126825
# life_expectancy                                          0.139654
# human_development_index                                  0.217556
#
#                                             new_cases_smoothed_per_million  \
# total_cases                                                       0.029708
# new_cases                                                         0.091018
# new_cases_smoothed                                                0.093602
# total_deaths                                                      0.007913
# new_deaths                                                        0.007527
# new_deaths_smoothed                                               0.006760
# total_cases_per_million                                           0.420705
# new_cases_per_million                                             0.674096
# new_cases_smoothed_per_million                                    1.000000
# total_deaths_per_million                                          0.227297
# new_deaths_per_million                                            0.217409
# new_deaths_smoothed_per_million                                   0.294967
# reproduction_rate                                                 0.095170
# total_tests                                                       0.086065
# new_tests                                                         0.118445
# total_tests_per_thousand                                          0.398755
# new_tests_per_thousand                                            0.352688
# new_tests_smoothed                                               -0.006677
# new_tests_smoothed_per_thousand                                   0.406225
# positive_rate                                                     0.420689
# tests_per_case                                                   -0.027197
# total_vaccinations                                               -0.054095
# people_vaccinated                                                -0.056517
# people_fully_vaccinated                                          -0.051416
# new_vaccinations                                                 -0.083430
# new_vaccinations_smoothed                                        -0.036854
# total_vaccinations_per_hundred                                    0.324491
# people_vaccinated_per_hundred                                     0.282741
# people_fully_vaccinated_per_hundred                               0.298315
# new_vaccinations_smoothed_per_million                             0.069616
# new_people_vaccinated_smoothed                                   -0.041456
# new_people_vaccinated_smoothed_per_hundred                       -0.047256
# stringency_index                                                 -0.073729
# population                                                       -0.035889
# population_density                                                0.023984
# median_age                                                        0.270562
# aged_65_older                                                     0.266836
# aged_70_older                                                     0.267053
# gdp_per_capita                                                    0.207591
# extreme_poverty                                                  -0.196174
# cardiovasc_death_rate                                            -0.149767
# diabetes_prevalence                                               0.032514
# female_smokers                                                    0.227716
# male_smokers                                                      0.025939
# handwashing_facilities                                            0.186806
# hospital_beds_per_thousand                                        0.159154
# life_expectancy                                                   0.215142
# human_development_index                                           0.273405
#
#                                             total_deaths_per_million  ...  \
# total_cases                                                 0.118575  ...
# new_cases                                                   0.078915  ...
# new_cases_smoothed                                          0.081610  ...
# total_deaths                                                0.130662  ...
# new_deaths                                                  0.039061  ...
# new_deaths_smoothed                                         0.040897  ...
# total_cases_per_million                                     0.616895  ...
# new_cases_per_million                                       0.163937  ...
# new_cases_smoothed_per_million                              0.227297  ...
# total_deaths_per_million                                    1.000000  ...
# new_deaths_per_million                                      0.184902  ...
# new_deaths_smoothed_per_million                             0.291588  ...
# reproduction_rate                                           0.007875  ...
# total_tests                                                 0.183761  ...
# new_tests                                                   0.132368  ...
# total_tests_per_thousand                                    0.269131  ...
# new_tests_per_thousand                                      0.134524  ...
# new_tests_smoothed                                         -0.039034  ...
# new_tests_smoothed_per_thousand                             0.118753  ...
# positive_rate                                               0.196476  ...
# tests_per_case                                             -0.056003  ...
# total_vaccinations                                         -0.063959  ...
# people_vaccinated                                          -0.059756  ...
# people_fully_vaccinated                                    -0.062149  ...
# new_vaccinations                                           -0.125397  ...
# new_vaccinations_smoothed                                  -0.041345  ...
# total_vaccinations_per_hundred                              0.289087  ...
# people_vaccinated_per_hundred                               0.331540  ...
# people_fully_vaccinated_per_hundred                         0.284613  ...
# new_vaccinations_smoothed_per_million                       0.035768  ...
# new_people_vaccinated_smoothed                             -0.045397  ...
# new_people_vaccinated_smoothed_per_hundred                 -0.041783  ...
# stringency_index                                           -0.225552  ...
# population                                                 -0.049977  ...
# population_density                                         -0.009101  ...
# median_age                                                  0.410451  ...
# aged_65_older                                               0.407372  ...
# aged_70_older                                               0.405510  ...
# gdp_per_capita                                              0.153302  ...
# extreme_poverty                                            -0.348404  ...
# cardiovasc_death_rate                                      -0.119591  ...
# diabetes_prevalence                                         0.029684  ...
# female_smokers                                              0.414332  ...
# male_smokers                                                0.110760  ...
# handwashing_facilities                                      0.412071  ...
# hospital_beds_per_thousand                                  0.227628  ...
# life_expectancy                                             0.334573  ...
# human_development_index                                     0.383648  ...
#
#                                             gdp_per_capita  extreme_poverty  \
# total_cases                                       0.015033        -0.036235
# new_cases                                         0.019298        -0.035504
# new_cases_smoothed                                0.019586        -0.036207
# total_deaths                                      0.005910        -0.043564
# new_deaths                                        0.006708        -0.045517
# new_deaths_smoothed                               0.006821        -0.046576
# total_cases_per_million                           0.296431        -0.304806
# new_cases_per_million                             0.161016        -0.162969
# new_cases_smoothed_per_million                    0.207591        -0.196174
# total_deaths_per_million                          0.153302        -0.348404
# new_deaths_per_million                            0.075323        -0.227132
# new_deaths_smoothed_per_million                   0.103968        -0.269261
# reproduction_rate                                 0.133194        -0.187400
# total_tests                                       0.113759        -0.043441
# new_tests                                         0.116499        -0.042700
# total_tests_per_thousand                          0.328856        -0.195984
# new_tests_per_thousand                            0.257534        -0.157086
# new_tests_smoothed                               -0.000961        -0.060556
# new_tests_smoothed_per_thousand                   0.304766        -0.201509
# positive_rate                                    -0.033451        -0.109349
# tests_per_case                                   -0.022683        -0.042694
# total_vaccinations                               -0.066064         0.027382
# people_vaccinated                                -0.063112         0.052443
# people_fully_vaccinated                          -0.060726         0.053869
# new_vaccinations                                 -0.095408         0.078804
# new_vaccinations_smoothed                        -0.021450        -0.031664
# total_vaccinations_per_hundred                    0.363278        -0.348946
# people_vaccinated_per_hundred                     0.358436        -0.367701
# people_fully_vaccinated_per_hundred               0.334189        -0.321897
# new_vaccinations_smoothed_per_million             0.234066        -0.247485
# new_people_vaccinated_smoothed                   -0.022160        -0.022251
# new_people_vaccinated_smoothed_per_hundred        0.112182        -0.124054
# stringency_index                                 -0.009519        -0.153451
# population                                       -0.028904        -0.025104
# population_density                                0.413516        -0.029913
# median_age                                        0.640961        -0.697796
# aged_65_older                                     0.490625        -0.573833
# aged_70_older                                     0.475336        -0.557505
# gdp_per_capita                                    1.000000        -0.504071
# extreme_poverty                                  -0.504071         1.000000
# cardiovasc_death_rate                            -0.476406         0.191066
# diabetes_prevalence                               0.159242        -0.395559
# female_smokers                                    0.328897        -0.408959
# male_smokers                                     -0.098517        -0.194968
# handwashing_facilities                            0.649348        -0.755279
# hospital_beds_per_thousand                        0.293811        -0.440751
# life_expectancy                                   0.682963        -0.749866
# human_development_index                           0.754456        -0.777683
#
#                                             cardiovasc_death_rate  \
# total_cases                                             -0.039849
# new_cases                                               -0.044222
# new_cases_smoothed                                      -0.045027
# total_deaths                                            -0.038108
# new_deaths                                              -0.035999
# new_deaths_smoothed                                     -0.036761
# total_cases_per_million                                 -0.200398
# new_cases_per_million                                   -0.116375
# new_cases_smoothed_per_million                          -0.149767
# total_deaths_per_million                                -0.119591
# new_deaths_per_million                                  -0.044163
# new_deaths_smoothed_per_million                         -0.057083
# reproduction_rate                                       -0.106286
# total_tests                                             -0.056845
# new_tests                                               -0.068046
# total_tests_per_thousand                                -0.109368
# new_tests_per_thousand                                  -0.094994
# new_tests_smoothed                                       0.006593
# new_tests_smoothed_per_thousand                         -0.131296
# positive_rate                                           -0.007700
# tests_per_case                                           0.019149
# total_vaccinations                                       0.009838
# people_vaccinated                                        0.010091
# people_fully_vaccinated                                  0.005305
# new_vaccinations                                         0.031202
# new_vaccinations_smoothed                               -0.018237
# total_vaccinations_per_hundred                          -0.325492
# people_vaccinated_per_hundred                           -0.323494
# people_fully_vaccinated_per_hundred                     -0.297914
# new_vaccinations_smoothed_per_million                   -0.198321
# new_people_vaccinated_smoothed                          -0.015344
# new_people_vaccinated_smoothed_per_hundred              -0.099387
# stringency_index                                        -0.033321
# population                                              -0.016815
# population_density                                      -0.175239
# median_age                                              -0.338607
# aged_65_older                                           -0.338058
# aged_70_older                                           -0.353158
# gdp_per_capita                                          -0.476406
# extreme_poverty                                          0.191066
# cardiovasc_death_rate                                    1.000000
# diabetes_prevalence                                      0.119743
# female_smokers                                          -0.157198
# male_smokers                                             0.424240
# handwashing_facilities                                  -0.022604
# hospital_beds_per_thousand                               0.032157
# life_expectancy                                         -0.470957
# human_development_index                                 -0.425313
#
#                                             diabetes_prevalence  \
# total_cases                                            0.005008
# new_cases                                              0.001034
# new_cases_smoothed                                     0.001110
# total_deaths                                           0.014258
# new_deaths                                             0.014447
# new_deaths_smoothed                                    0.014868
# total_cases_per_million                                0.037534
# new_cases_per_million                                  0.028528
# new_cases_smoothed_per_million                         0.032514
# total_deaths_per_million                               0.029684
# new_deaths_per_million                                 0.034519
# new_deaths_smoothed_per_million                        0.047132
# reproduction_rate                                      0.008498
# total_tests                                            0.055582
# new_tests                                              0.045655
# total_tests_per_thousand                               0.058685
# new_tests_per_thousand                                 0.060956
# new_tests_smoothed                                     0.044857
# new_tests_smoothed_per_thousand                        0.074895
# positive_rate                                          0.007443
# tests_per_case                                         0.040126
# total_vaccinations                                     0.038725
# people_vaccinated                                      0.036204
# people_fully_vaccinated                                0.032986
# new_vaccinations                                       0.054078
# new_vaccinations_smoothed                              0.008213
# total_vaccinations_per_hundred                         0.062822
# people_vaccinated_per_hundred                          0.070214
# people_fully_vaccinated_per_hundred                    0.070782
# new_vaccinations_smoothed_per_million                  0.084321
# new_people_vaccinated_smoothed                         0.006401
# new_people_vaccinated_smoothed_per_hundred             0.049001
# stringency_index                                       0.082112
# population                                             0.002649
# population_density                                     0.012604
# median_age                                             0.155971
# aged_65_older                                         -0.041915
# aged_70_older                                         -0.073634
# gdp_per_capita                                         0.159242
# extreme_poverty                                       -0.395559
# cardiovasc_death_rate                                  0.119743
# diabetes_prevalence                                    1.000000
# female_smokers                                         0.019145
# male_smokers                                           0.188250
# handwashing_facilities                                 0.483493
# hospital_beds_per_thousand                            -0.085097
# life_expectancy                                        0.237069
# human_development_index                                0.209637
#
#                                             female_smokers  male_smokers  \
# total_cases                                       0.001640     -0.003540
# new_cases                                         0.006417      0.000662
# new_cases_smoothed                                0.006482      0.000628
# total_deaths                                     -0.007014     -0.002238
# new_deaths                                       -0.005814      0.002964
# new_deaths_smoothed                              -0.005954      0.003111
# total_cases_per_million                           0.351466      0.060653
# new_cases_per_million                             0.186389      0.021394
# new_cases_smoothed_per_million                    0.227716      0.025939
# total_deaths_per_million                          0.414332      0.110760
# new_deaths_per_million                            0.255078      0.087399
# new_deaths_smoothed_per_million                   0.314010      0.109264
# reproduction_rate                                 0.122817     -0.010698
# total_tests                                       0.059988     -0.050464
# new_tests                                         0.067622     -0.040162
# total_tests_per_thousand                          0.216623      0.089166
# new_tests_per_thousand                            0.174326      0.125399
# new_tests_smoothed                               -0.066940      0.104736
# new_tests_smoothed_per_thousand                   0.196811      0.131384
# positive_rate                                     0.043369     -0.027010
# tests_per_case                                   -0.073882      0.093851
# total_vaccinations                               -0.105653      0.027172
# people_vaccinated                                -0.094875     -0.003926
# people_fully_vaccinated                          -0.093367     -0.004725
# new_vaccinations                                 -0.131728      0.029024
# new_vaccinations_smoothed                        -0.060203      0.024363
# total_vaccinations_per_hundred                    0.146422     -0.042885
# people_vaccinated_per_hundred                     0.147270     -0.062181
# people_fully_vaccinated_per_hundred               0.125832     -0.073700
# new_vaccinations_smoothed_per_million             0.100565      0.016590
# new_people_vaccinated_smoothed                   -0.055225      0.010956
# new_people_vaccinated_smoothed_per_hundred        0.039217      0.016320
# stringency_index                                 -0.092089      0.045278
# population                                       -0.064437      0.017192
# population_density                               -0.054754     -0.000094
# median_age                                        0.653701      0.185161
# aged_65_older                                     0.750148      0.090673
# aged_70_older                                     0.751710      0.089792
# gdp_per_capita                                    0.328897     -0.098517
# extreme_poverty                                  -0.408959     -0.194968
# cardiovasc_death_rate                            -0.157198      0.424240
# diabetes_prevalence                               0.019145      0.188250
# female_smokers                                    1.000000      0.211192
# male_smokers                                      0.211192      1.000000
# handwashing_facilities                            0.294144      0.331640
# hospital_beds_per_thousand                        0.482090      0.354265
# life_expectancy                                   0.476960      0.059336
# human_development_index                           0.567648      0.094800
#
#                                             handwashing_facilities  \
# total_cases                                               0.032427
# new_cases                                                 0.030710
# new_cases_smoothed                                        0.031274
# total_deaths                                              0.042517
# new_deaths                                                0.044504
# new_deaths_smoothed                                       0.045438
# total_cases_per_million                                   0.392375
# new_cases_per_million                                     0.136974
# new_cases_smoothed_per_million                            0.186806
# total_deaths_per_million                                  0.412071
# new_deaths_per_million                                    0.238958
# new_deaths_smoothed_per_million                           0.320232
# reproduction_rate                                         0.156054
# total_tests                                               0.022820
# new_tests                                                 0.012141
# total_tests_per_thousand                                  0.313532
# new_tests_per_thousand                                    0.116401
# new_tests_smoothed                                        0.042138
# new_tests_smoothed_per_thousand                           0.285696
# positive_rate                                             0.235275
# tests_per_case                                           -0.002891
# total_vaccinations                                       -0.005324
# people_vaccinated                                        -0.010734
# people_fully_vaccinated                                  -0.022149
# new_vaccinations                                         -0.042397
# new_vaccinations_smoothed                                 0.039128
# total_vaccinations_per_hundred                            0.368888
# people_vaccinated_per_hundred                             0.377907
# people_fully_vaccinated_per_hundred                       0.340841
# new_vaccinations_smoothed_per_million                     0.241475
# new_people_vaccinated_smoothed                            0.036162
# new_people_vaccinated_smoothed_per_hundred                0.116914
# stringency_index                                          0.260443
# population                                                0.036740
# population_density                                        0.095271
# median_age                                                0.783379
# aged_65_older                                             0.635588
# aged_70_older                                             0.631393
# gdp_per_capita                                            0.649348
# extreme_poverty                                          -0.755279
# cardiovasc_death_rate                                    -0.022604
# diabetes_prevalence                                       0.483493
# female_smokers                                            0.294144
# male_smokers                                              0.331640
# handwashing_facilities                                    1.000000
# hospital_beds_per_thousand                                0.460257
# life_expectancy                                           0.815155
# human_development_index                                   0.835810
#
#                                             hospital_beds_per_thousand  \
# total_cases                                                   0.003269
# new_cases                                                     0.016842
# new_cases_smoothed                                            0.016802
# total_deaths                                                 -0.006930
# new_deaths                                                   -0.002407
# new_deaths_smoothed                                          -0.002455
# total_cases_per_million                                       0.226266
# new_cases_per_million                                         0.126825
# new_cases_smoothed_per_million                                0.159154
# total_deaths_per_million                                      0.227628
# new_deaths_per_million                                        0.139183
# new_deaths_smoothed_per_million                               0.184208
# reproduction_rate                                             0.084833
# total_tests                                                  -0.013811
# new_tests                                                    -0.004304
# total_tests_per_thousand                                      0.110083
# new_tests_per_thousand                                        0.088958
# new_tests_smoothed                                            0.033973
# new_tests_smoothed_per_thousand                               0.087087
# positive_rate                                                -0.003651
# tests_per_case                                                0.030025
# total_vaccinations                                           -0.035889
# people_vaccinated                                            -0.054146
# people_fully_vaccinated                                      -0.049818
# new_vaccinations                                             -0.057429
# new_vaccinations_smoothed                                    -0.008096
# total_vaccinations_per_hundred                                0.114039
# people_vaccinated_per_hundred                                 0.111787
# people_fully_vaccinated_per_hundred                           0.100886
# new_vaccinations_smoothed_per_million                         0.114265
# new_people_vaccinated_smoothed                               -0.018768
# new_people_vaccinated_smoothed_per_hundred                    0.043203
# stringency_index                                             -0.039378
# population                                                   -0.021989
# population_density                                            0.295561
# median_age                                                    0.633950
# aged_65_older                                                 0.613590
# aged_70_older                                                 0.614642
# gdp_per_capita                                                0.293811
# extreme_poverty                                              -0.440751
# cardiovasc_death_rate                                         0.032157
# diabetes_prevalence                                          -0.085097
# female_smokers                                                0.482090
# male_smokers                                                  0.354265
# handwashing_facilities                                        0.460257
# hospital_beds_per_thousand                                    1.000000
# life_expectancy                                               0.432233
# human_development_index                                       0.558551
#
#                                             life_expectancy  \
# total_cases                                        0.017817
# new_cases                                          0.023590
# new_cases_smoothed                                 0.023949
# total_deaths                                       0.015896
# new_deaths                                         0.016258
# new_deaths_smoothed                                0.016606
# total_cases_per_million                            0.350034
# new_cases_per_million                              0.139654
# new_cases_smoothed_per_million                     0.215142
# total_deaths_per_million                           0.334573
# new_deaths_per_million                             0.130696
# new_deaths_smoothed_per_million                    0.200028
# reproduction_rate                                  0.208476
# total_tests                                        0.062729
# new_tests                                          0.070498
# total_tests_per_thousand                           0.245282
# new_tests_per_thousand                             0.206590
# new_tests_smoothed                                 0.042435
# new_tests_smoothed_per_thousand                    0.257863
# positive_rate                                      0.083980
# tests_per_case                                     0.021942
# total_vaccinations                                -0.061068
# people_vaccinated                                 -0.075160
# people_fully_vaccinated                           -0.075640
# new_vaccinations                                  -0.114083
# new_vaccinations_smoothed                          0.001292
# total_vaccinations_per_hundred                     0.435881
# people_vaccinated_per_hundred                      0.438419
# people_fully_vaccinated_per_hundred                0.400430
# new_vaccinations_smoothed_per_million              0.274807
# new_people_vaccinated_smoothed                    -0.006002
# new_people_vaccinated_smoothed_per_hundred         0.139243
# stringency_index                                   0.066580
# population                                        -0.017598
# population_density                                 0.230531
# median_age                                         0.846703
# aged_65_older                                      0.731848
# aged_70_older                                      0.717198
# gdp_per_capita                                     0.682963
# extreme_poverty                                   -0.749866
# cardiovasc_death_rate                             -0.470957
# diabetes_prevalence                                0.237069
# female_smokers                                     0.476960
# male_smokers                                       0.059336
# handwashing_facilities                             0.815155
# hospital_beds_per_thousand                         0.432233
# life_expectancy                                    1.000000
# human_development_index                            0.913216
#
#                                             human_development_index
# total_cases                                                0.041663
# new_cases                                                  0.045534
# new_cases_smoothed                                         0.046370
# total_deaths                                               0.038723
# new_deaths                                                 0.040794
# new_deaths_smoothed                                        0.041722
# total_cases_per_million                                    0.412741
# new_cases_per_million                                      0.217556
# new_cases_smoothed_per_million                             0.273405
# total_deaths_per_million                                   0.383648
# new_deaths_per_million                                     0.214564
# new_deaths_smoothed_per_million                            0.275804
# reproduction_rate                                          0.205816
# total_tests                                                0.102113
# new_tests                                                  0.110478
# total_tests_per_thousand                                   0.295320
# new_tests_per_thousand                                     0.244492
# new_tests_smoothed                                         0.023248
# new_tests_smoothed_per_thousand                            0.288266
# positive_rate                                              0.078969
# tests_per_case                                            -0.000848
# total_vaccinations                                        -0.061146
# people_vaccinated                                         -0.065472
# people_fully_vaccinated                                   -0.068504
# new_vaccinations                                          -0.117154
# new_vaccinations_smoothed                                  0.009865
# total_vaccinations_per_hundred                             0.416152
# people_vaccinated_per_hundred                              0.421692
# people_fully_vaccinated_per_hundred                        0.386115
# new_vaccinations_smoothed_per_million                      0.293842
# new_people_vaccinated_smoothed                             0.003370
# new_people_vaccinated_smoothed_per_hundred                 0.141941
# stringency_index                                           0.081345
# population                                                 0.000651
# population_density                                         0.180864
# median_age                                                 0.898642
# aged_65_older                                              0.780636
# aged_70_older                                              0.768540
# gdp_per_capita                                             0.754456
# extreme_poverty                                           -0.777683
# cardiovasc_death_rate                                     -0.425313
# diabetes_prevalence                                        0.209637
# female_smokers                                             0.567648
# male_smokers                                               0.094800
# handwashing_facilities                                     0.835810
# hospital_beds_per_thousand                                 0.558551
# life_expectancy                                            0.913216
# human_development_index                                    1.000000
#
# [48 rows x 48 columns]

# %%
sns.heatmap(df_Russia2020.corr(), 
            xticklabels=df_Russia2021.corr().columns,
            yticklabels=df_Russia2021.corr().columns)

# %% [markdown]
# # **Скаттер графики по годам**

# %%
df_Russia2021[['new_deaths', 'new_tests']].plot.scatter(
    x = 'new_tests',
    y = 'new_deaths',
    c = 'White'
)

# %%
df_Russia2020[['new_deaths', 'new_tests']].plot.scatter(
    x = 'new_tests',
    y = 'new_deaths',
    c = 'White'
)

# %%
df_Russia2022[['new_deaths', 'new_tests']].plot.scatter(
    x = 'new_tests',
    y = 'new_deaths',
    c = 'White'
)

# %%
df_Russia2022[['new_deaths', 'new_tests']]
# Out:
#         new_deaths  new_tests
# 156689       825.0        NaN
# 156690       788.0        NaN
# 156691       812.0        NaN
# 156692       810.0        NaN
# 156693       804.0        NaN
# ...            ...        ...
# 156916        57.0        NaN
# 156917        62.0        NaN
# 156918        62.0        NaN
# 156919        64.0        NaN
# 156920        67.0        NaN
#
# [232 rows x 2 columns]

# %%
df_Russia2021[['new_deaths', 'new_tests']]
# Out:
#         new_deaths  new_tests
# 156324       527.0   386001.0
# 156325       437.0        NaN
# 156326       495.0        NaN
# 156327       473.0   217791.0
# 156328       503.0   268620.0
# ...            ...        ...
# 156684       912.0        NaN
# 156685       906.0        NaN
# 156686       903.0        NaN
# 156687       905.0        NaN
# 156688       880.0        NaN
#
# [365 rows x 2 columns]

# %%
lm = sm.OLS.from_formula('people_vaccinated ~ new_cases', df_Russia2021)
result = lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      people_vaccinated   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                     653.9
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):           6.99e-75
# Time:                        17:49:29   Log-Likelihood:                -4933.8
# No. Observations:                 279   AIC:                             9872.
# Df Residuals:                     277   BIC:                             9879.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.827e+06   1.64e+06     -1.728      0.085   -6.05e+06    3.94e+05
# new_cases   1898.6145     74.245     25.572      0.000    1752.458    2044.771
# ==============================================================================
# Omnibus:                       13.931   Durbin-Watson:                   0.037
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               22.755
# Skew:                           0.307   Prob(JB):                     1.15e-05
# Kurtosis:                       4.257   Cond. No.                     5.18e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.rcParams['figure.figsize'] = [10, 10]
df_Russia2020[['total_deaths', 'total_tests']].plot.scatter(
    x = 'total_deaths',
    y = 'total_tests',
    c = 'White'
)

# %%
lm = sm.OLS.from_formula('new_tests ~ new_deaths', df_Russia2020)
result = lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              new_tests   R-squared:                       0.656
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     523.4
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):           1.63e-65
# Time:                        17:49:34   Log-Likelihood:                -3532.2
# No. Observations:                 276   AIC:                             7068.
# Df Residuals:                     274   BIC:                             7076.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.684e+05   8321.045     20.234      0.000    1.52e+05    1.85e+05
# new_deaths   762.0423     33.307     22.879      0.000     696.471     827.613
# ==============================================================================
# Omnibus:                        0.684   Durbin-Watson:                   0.255
# Prob(Omnibus):                  0.710   Jarque-Bera (JB):                0.430
# Skew:                           0.043   Prob(JB):                        0.806
# Kurtosis:                       3.174   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = df_Russia2021.drop(columns='new_tests')
x
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 156324      RUS    Europe   Russia  2021-01-01    3153960.0    26613.0
# 156325      RUS    Europe   Russia  2021-01-02    3179898.0    25938.0
# 156326      RUS    Europe   Russia  2021-01-03    3203743.0    23845.0
# 156327      RUS    Europe   Russia  2021-01-04    3226758.0    23015.0
# 156328      RUS    Europe   Russia  2021-01-05    3250713.0    23955.0
# ...         ...       ...      ...         ...          ...        ...
# 156684      RUS    Europe   Russia  2021-12-27   10236301.0    23036.0
# 156685      RUS    Europe   Russia  2021-12-28   10258052.0    21751.0
# 156686      RUS    Europe   Russia  2021-12-29   10279009.0    20957.0
# 156687      RUS    Europe   Russia  2021-12-30   10299923.0    20914.0
# 156688      RUS    Europe   Russia  2021-12-31   10320405.0    20482.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 156324           27238.571       56798.0       527.0              544.714
# 156325           26825.000       57235.0       437.0              528.000
# 156326           26253.000       57730.0       495.0              521.429
# 156327           25631.857       58203.0       473.0              520.571
# 156328           25255.714       58706.0       503.0              514.143
# ...                    ...           ...         ...                  ...
# 156684           24573.000      299077.0       912.0              963.714
# 156685           24015.286      299983.0       906.0              950.571
# 156686           23432.286      300886.0       903.0              937.714
# 156687           22784.857      301791.0       905.0              927.857
# 156688           22207.714      302671.0       880.0              914.714
#
#         ...  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 156324  ...       24765.954              0.1                431.297
# 156325  ...       24765.954              0.1                431.297
# 156326  ...       24765.954              0.1                431.297
# 156327  ...       24765.954              0.1                431.297
# 156328  ...       24765.954              0.1                431.297
# ...     ...             ...              ...                    ...
# 156684  ...       24765.954              0.1                431.297
# 156685  ...       24765.954              0.1                431.297
# 156686  ...       24765.954              0.1                431.297
# 156687  ...       24765.954              0.1                431.297
# 156688  ...       24765.954              0.1                431.297
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 156324                 6.18            23.4          58.3
# 156325                 6.18            23.4          58.3
# 156326                 6.18            23.4          58.3
# 156327                 6.18            23.4          58.3
# 156328                 6.18            23.4          58.3
# ...                     ...             ...           ...
# 156684                 6.18            23.4          58.3
# 156685                 6.18            23.4          58.3
# 156686                 6.18            23.4          58.3
# 156687                 6.18            23.4          58.3
# 156688                 6.18            23.4          58.3
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 156324                     NaN                        8.05            72.58
# 156325                     NaN                        8.05            72.58
# 156326                     NaN                        8.05            72.58
# 156327                     NaN                        8.05            72.58
# 156328                     NaN                        8.05            72.58
# ...                        ...                         ...              ...
# 156684                     NaN                        8.05            72.58
# 156685                     NaN                        8.05            72.58
# 156686                     NaN                        8.05            72.58
# 156687                     NaN                        8.05            72.58
# 156688                     NaN                        8.05            72.58
#
#         human_development_index
# 156324                    0.824
# 156325                    0.824
# 156326                    0.824
# 156327                    0.824
# 156328                    0.824
# ...                         ...
# 156684                    0.824
# 156685                    0.824
# 156686                    0.824
# 156687                    0.824
# 156688                    0.824
#
# [365 rows x 52 columns]

# %% [markdown]
# # **Данные по некоторым странам**

# %%
df_Russia = df.loc[(df['location'] == 'Russia') & (df['date'] >= '2022-01-01') & (df['date'] < '2022-09-01')] #Данные о России за 2022

# %%
df_China  = df.loc[(df['location'] == 'China') & (df['date'] >= '2022-01-01') & (df['date'] < '2022-09-01')] #Данные о Китае за 2022

# %%
df_Australia = df.loc[(df['location'] == 'Australia') & (df['date'] >= '2022-01-01') & (df['date'] < '2022-09-01')] #Данные об Австралии за 2022

# %%
df_Germany = df.loc[(df['location'] == 'Germany') & (df['date'] >= '2022-01-01') & (df['date'] < '2022-09-01')] #Данные о Германии за 2022

# %%
from pandas.core.internals.managers import T

# %%
def plot_country(data, country):
  plt.figure(figsize=(30,10))

  plt.plot(data['date'], data['new_cases'],
  color = '#33cccc', 
  label = 'Total cases',
  marker = 'o')

  plt.title('New cases over the time in ' + country, size=30)
  plt.ylabel('Cases', size=20)
  plt.xlabel('Timeline', size=20)
  plt.xticks(rotation=90, size=10)
  plt.yticks(size=15)

# %%
plot_country(df_Australia, 'Australia')

# %%
plot_country(df_Germany, 'Germany')

# %%
plot_country(df_Russia, 'Russia')

# %%
plot_country(df_China, 'China')

# %% [markdown]
# # **Предсказатель данных**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

# %%
df = pd.read_csv('/content/new_cases.csv')
df = df.drop(df[df.date >= '2021-01-01'].index)
df = df.drop(df[df.date < '2020-01-01'].index)
df
# Out:
#            date     World  Afghanistan   Africa  Albania  Algeria  Andorra  \
# 0    2020-01-22       0.0          NaN      NaN      NaN      NaN      NaN
# 1    2020-01-23     100.0          NaN      NaN      NaN      NaN      NaN
# 2    2020-01-24     287.0          NaN      NaN      NaN      NaN      NaN
# 3    2020-01-25     493.0          NaN      NaN      NaN      NaN      NaN
# 4    2020-01-26     683.0          NaN      NaN      NaN      NaN      NaN
# ..          ...       ...          ...      ...      ...      ...      ...
# 340  2020-12-27  413099.0         84.0  18675.0    499.0    392.0     15.0
# 341  2020-12-28  497907.0        159.0  15199.0    318.0    382.0     54.0
# 342  2020-12-29  671042.0        140.0  20128.0    574.0    357.0     44.0
# 343  2020-12-30  724900.0        183.0  30593.0    581.0    323.0     64.0
# 344  2020-12-31  840688.0          0.0  29789.0    589.0    299.0     66.0
#
#      Angola  Anguilla  Antigua and Barbuda  ...  Uruguay  Uzbekistan  Vanuatu  \
# 0       NaN       NaN                  NaN  ...      NaN         NaN      NaN
# 1       NaN       NaN                  NaN  ...      NaN         NaN      NaN
# 2       NaN       NaN                  NaN  ...      NaN         NaN      NaN
# 3       NaN       NaN                  NaN  ...      NaN         NaN      NaN
# 4       NaN       NaN                  NaN  ...      NaN         NaN      NaN
# ..      ...       ...                  ...  ...      ...         ...      ...
# 340    91.0       0.0                  0.0  ...    510.0        85.0      0.0
# 341    56.0       1.0                  3.0  ...    578.0        81.0      0.0
# 342    75.0       0.0                  0.0  ...    656.0        75.0      0.0
# 343    62.0       0.0                  0.0  ...    518.0        78.0      0.0
# 344   120.0       0.0                  1.0  ...    639.0        75.0      0.0
#
#      Vatican  Venezuela  Vietnam  Wallis and Futuna  Yemen  Zambia  Zimbabwe
# 0        NaN        NaN      NaN                NaN    NaN     NaN       NaN
# 1        NaN        NaN      2.0                NaN    NaN     NaN       NaN
# 2        NaN        NaN      0.0                NaN    NaN     NaN       NaN
# 3        NaN        NaN      0.0                NaN    NaN     NaN       NaN
# 4        NaN        NaN      0.0                NaN    NaN     NaN       NaN
# ..       ...        ...      ...                ...    ...     ...       ...
# 340      0.0      365.0      1.0                0.0    2.0   163.0     114.0
# 341      0.0      320.0     10.0                0.0    2.0   109.0      71.0
# 342      0.0      225.0      3.0                0.0    0.0   234.0     177.0
# 343      0.0      260.0      2.0                0.0    1.0   285.0     300.0
# 344      0.0      437.0      9.0                0.0    2.0   263.0     242.0
#
# [345 rows x 230 columns]

# %%
df['index'] = np.arange(1, len(df) + 1)

# %%
df[['index', 'World']]
# Out:
#      index     World
# 0        1       0.0
# 1        2     100.0
# 2        3     287.0
# 3        4     493.0
# 4        5     683.0
# ..     ...       ...
# 340    341  413099.0
# 341    342  497907.0
# 342    343  671042.0
# 343    344  724900.0
# 344    345  840688.0
#
# [345 rows x 2 columns]

# %%
index_x = np.array(df['index']).reshape(-1, 1)

# %%
cases_y = np.array(df['World']).reshape(-1, 1)

# %%
plt.style.use('dark_background')
plt.plot(cases_y, 'wo')

# %%
poly = PolynomialFeatures(degree=3)
index_x = poly.fit_transform(index_x)
index_x
# Out:
# array([[1.0000000e+00, 1.0000000e+00, 1.0000000e+00, 1.0000000e+00],
#        [1.0000000e+00, 2.0000000e+00, 4.0000000e+00, 8.0000000e+00],
#        [1.0000000e+00, 3.0000000e+00, 9.0000000e+00, 2.7000000e+01],
#        ...,
#        [1.0000000e+00, 3.4300000e+02, 1.1764900e+05, 4.0353607e+07],
#        [1.0000000e+00, 3.4400000e+02, 1.1833600e+05, 4.0707584e+07],
#        [1.0000000e+00, 3.4500000e+02, 1.1902500e+05, 4.1063625e+07]])

# %%
model = linear_model.LinearRegression()
model.fit(index_x,cases_y)
accuracy = model.score(index_x,cases_y)
round(accuracy*100,3)
# Out:
# 94.125

# %%
prediction = model.predict(index_x)

# %%
prediction = model.predict(index_x)
plt.style.use('dark_background')
plt.plot(cases_y, 'wo')
plt.plot(prediction, '--b')

# %%
prediction = model.predict(index_x)
plt.style.use('dark_background')
plt.plot(cases_y, 'wo')
plt.plot(prediction, '--b')
days = 10
print('Will be', round(int(model.predict(poly.fit_transform([[345+days]])))), 
      'new cases over the', days, 'days')

x_prediction = np.array(list(range(1,345+days))).reshape(-1,1)
y_prediction = model.predict(poly.fit_transform(x_prediction))
plt.plot(y_prediction,'ro')
plt.plot(prediction, '--b')
plt.show()
# Out:
# Will be 758000 new cases over the 10 days
